# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('csv-data\\cleaned_dataset_analysis.csv')

# %%
df.describe()
# Out:
#            Zip Code         Price  Number of Rooms  Livable Space (m2)  \
# count  10701.000000  1.070100e+04     10701.000000        10701.000000
# mean    4685.047192  7.471396e+05         3.590973          251.505000
# std     3254.051241  8.492094e+05         2.175236          225.919926
# min     1000.000000  2.750000e+04         0.000000           13.000000
# 25%     1640.000000  2.790000e+05         2.000000          111.000000
# 50%     3320.000000  5.250000e+05         3.000000          200.000000
# 75%     8400.000000  8.500000e+05         4.000000          315.000000
# max     9992.000000  1.050000e+07        40.000000         5596.000000
#
#        Fully Equipped Kitchen    Furnished     Open Fire       Terrace  \
# count            10701.000000  10701.00000  10701.000000  10701.000000
# mean                 0.600037      0.03523      0.090178      0.415475
# std                  0.489913      0.18437      0.286451      0.492827
# ...

# %%
df.shape
# Out:
# (10701, 27)

# %%
plt.figure(figsize = [10, 8])
#plt.style.use('ggplot')
sns.set_style('whitegrid')
#sns.histplot(df, x = 'Price')
#sns.histplot(df, x = 'Price', binwidth=50000)
#sns.histplot(df, x = 'Price', bins=20)
sns.histplot(df, x='Price', bins=30, kde=True)
#sns.histplot(df, x = 'Price', log_scale=True)
plt.title("Distribution of Property Prices", fontsize = 16, fontweight = 'bold')
plt.xlabel('Price (€)', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.ylabel('Count', fontsize = 14, fontweight = 'bold', loc = 'top')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
plt.figure(figsize = [10, 8])
sns.set_style('whitegrid')
sns.boxplot(df, x = 'Price', flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 8})
#plt.xscale('log')
q1, q2, q3 = df['Price'].quantile([0.25, 0.5, 0.75])
plt.axvline(q1, color='blue', linestyle='--', label='Q1')
plt.axvline(q2, color='green', linestyle='-', label='Median')
plt.axvline(q3, color='red', linestyle='--', label='Q3')
plt.legend()

plt.title('Statistics of Property Prices', fontsize = 16, fontweight = 'bold')
plt.xlabel('Price (€)', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.ylabel('Value', fontsize = 14, fontweight = 'bold', loc = 'top')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
sns.catplot(data=df, x='Price', col='Province', kind='box', col_wrap=4)

# %%
sns.boxplot(df, x = 'Livable Space (m2)', flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 8})
q1, q2, q3 = df['Livable Space (m2)'].quantile([0.25, 0.5, 0.75])
plt.axvline(q1, color='blue', linestyle='--', label='Q1')
plt.axvline(q2, color='green', linestyle='-', label='Median')
plt.axvline(q3, color='red', linestyle='--', label='Q3')
plt.legend()

plt.title('Statistics for Livable Space', fontsize = 16, fontweight = 'bold')
plt.xlabel('Livable Space (m2)', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()
plt.show()

# %%
plt.figure(figsize = [10, 8])
#plt.style.use('ggplot')
sns.set_style('whitegrid')
#sns.histplot(df, x = 'Livable Space (m2)')
#sns.histplot(df, x = 'Livable Space (m2)', binwidth=50000)
#sns.histplot(df, x = 'Livable Space (m2)', bins=20)
sns.histplot(df, x='Livable Space (m2)', bins=30, kde=True)
#sns.histplot(df, x = 'Livable Space (m2)', log_scale=True)
plt.title("Distribution of Property Surface", fontsize = 16, fontweight = 'bold')
plt.xlabel('Livable Space', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.ylabel('Count', fontsize = 14, fontweight = 'bold', loc = 'top')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
#Calculate quartiles and IQR
Q1 = df['Price'].quantile(0.25)  # (25%)
Q3 = df['Price'].quantile(0.75)  # (75%)
IQR = Q3 - Q1  

# Calculate limits for outliers
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

no_outliers_price = df[(df['Price'] > lower) & (df['Price'] < upper)]
print(f"Lower limit: {lower}")
print(f"Upper limit: {upper}")
outliers = df[(df['Price'] < lower) | (df['Price'] > upper)]
print("\nOutliers:")
print(len(outliers))
print(outliers)

print("\nNo Outliers:")
print(len(no_outliers_price))
print(no_outliers_price)
# Out:
# Lower limit: -577500.0
# Upper limit: 1706500.0
#
# Outliers:
# 819
#                   Locality  Zip Code                     Province  \
# 4                Kalmthout      2920          Province of Antwerp
# 11                   Uccle      1180      Brussels-Capital Region
# 12               Bruxelles      1000      Brussels-Capital Region
# 20           Sint-idesbald      8670    Province of West Flanders
# 24                   Uccle      1180      Brussels-Capital Region
# ...                    ...       ...                          ...
# 10667              Belsele      9111    Province of East Flanders
# 10686              Ixelles      1050      Brussels-Capital Region
# 10688                Lasne      1380  Province of Walloon Brabant
# 10693  Woluwe-saint-pierre      1150      Brussels-Capital Region
# 10694             Sprimont      4140            Province of Liège
#
#       Type of Property   Subtype of Property      Price  Number of Rooms  \
# ...

# %%
no_outliers_price.describe()
# Out:
#           Zip Code         Price  Number of Rooms  Livable Space (m2)  \
# count  9882.000000  9.882000e+03      9882.000000         9882.000000
# mean   4736.551508  5.569639e+05         3.406598          223.602105
# std    3247.456336  3.624072e+05         1.846950          174.559201
# min    1000.000000  2.750000e+04         0.000000           13.000000
# 25%    1730.000000  2.690000e+05         2.000000          106.000000
# 50%    3586.500000  4.500000e+05         3.000000          185.000000
# 75%    8420.000000  7.490000e+05         4.000000          291.000000
# max    9992.000000  1.700000e+06        34.000000         4000.000000
#
#        Fully Equipped Kitchen    Furnished    Open Fire      Terrace  \
# count             9882.000000  9882.000000  9882.000000  9882.000000
# mean                 0.599474     0.033495     0.085914     0.424307
# std                  0.490030     0.179935     0.280251     0.494262
# ...

# %%
no_outliers_price.shape
# Out:
# (9882, 27)

# %%
#Calculate quartiles and IQR
Q1 = df['Livable Space (m2)'].quantile(0.25)  # (25%)
Q3 = df['Livable Space (m2)'].quantile(0.75)  # (75%)
IQR = Q3 - Q1  

# Calculate limits for outliers
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

no_outliers_space = no_outliers_price[(no_outliers_price['Livable Space (m2)'] > lower) & (df['Livable Space (m2)'] < upper)]
print(f"Lower limit: {lower}")
print(f"Upper limit: {upper}")
outliers = no_outliers_price[(no_outliers_price['Livable Space (m2)'] < lower) | (df['Livable Space (m2)'] > upper)]
print("\nOutliers:")
print(len(outliers))
print(outliers)

print("\nNo Outliers:")
print(len(no_outliers_space))
print(no_outliers_space)
# Out:
# Lower limit: -195.0
# Upper limit: 621.0
#
# Outliers:
# 245
#                    Locality  Zip Code                     Province  \
# 50                 Mechelen      2812          Province of Antwerp
# 82                Antwerpen      2018          Province of Antwerp
# 120          Geraardsbergen      9500    Province of East Flanders
# 146              Schaerbeek      1030      Brussels-Capital Region
# 149                Waterloo      1410  Province of Walloon Brabant
# ...                     ...       ...                          ...
# 10525    Sint-pieters-leeuw      1600  Province of Flemish Brabant
# 10532    Sint-pieters-leeuw      1600  Province of Flemish Brabant
# 10550                Brugge      8000    Province of West Flanders
# 10570  Houthalen-helchteren      3530          Province of Limburg
# 10624                 Temse      9140    Province of East Flanders
#
#       Type of Property   Subtype of Property      Price  Number of Rooms  \
# ...

# %%
no_outliers_space.describe()
# Out:
#           Zip Code         Price  Number of Rooms  Livable Space (m2)  \
# count  9636.000000  9.636000e+03      9636.000000         9636.000000
# mean   4723.625778  5.432599e+05         3.328456          207.019406
# std    3251.406098  3.518417e+05         1.634712          124.312792
# min    1000.000000  2.750000e+04         0.000000           13.000000
# 25%    1700.000000  2.650000e+05         2.000000          105.000000
# 50%    3542.500000  4.400000e+05         3.000000          180.000000
# 75%    8420.000000  7.290000e+05         4.000000          281.000000
# max    9992.000000  1.700000e+06        18.000000          620.000000
#
#        Fully Equipped Kitchen    Furnished    Open Fire      Terrace  \
# count             9636.000000  9636.000000  9636.000000  9636.000000
# mean                 0.602740     0.033313     0.084994     0.428290
# std                  0.489356     0.179461     0.278887     0.494857
# ...

# %%
no_outliers_space.shape
# Out:
# (9636, 27)

# %%
no_outliers_space.to_csv('csv-data\\no_outliers_dataset.csv', index=False)

# %%
sns.boxplot(no_outliers_space, x = 'Livable Space (m2)', flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 8})
q1, q2, q3 = no_outliers_space['Livable Space (m2)'].quantile([0.25, 0.5, 0.75])
plt.axvline(q1, color='blue', linestyle='--', label='Q1')
plt.axvline(q2, color='green', linestyle='-', label='Median')
plt.axvline(q3, color='red', linestyle='--', label='Q3')
plt.legend()

plt.title('Statistics for Livable Space', fontsize = 16, fontweight = 'bold')
plt.xlabel('Livable Space (m2)', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()
plt.show()

# %%
plt.figure(figsize = [8, 5])
#plt.style.use('ggplot')
sns.set_style('whitegrid')
#sns.histplot(df_without_outliers, x = 'Livable Space (m2)')
#sns.histplot(df_without_outliers, x = 'Livable Space (m2)', binwidth=50000)
#sns.histplot(df_without_outliers, x = 'Livable Space (m2)', bins=20)
ax = sns.histplot(no_outliers_space, x='Livable Space (m2)', bins=10)
#sns.histplot(df_without_outliers, x = 'Livable Space (m2)', log_scale=True)

# Custom ticks for bins
bin_edges = ax.patches  # Get the bar patches (bin containers)
for patch in bin_edges:
    x_bin_center = patch.get_x() + patch.get_width() / 2  # Calculate bin center
    height = patch.get_height()  # Get bar height
    # Annotate the bar with the height value
    ax.text(x_bin_center, height, str(int(height)), ha='center', va='bottom', fontsize=12, color='black')

# Optional: Custom bin labels
# Example: Replace bin labels with "Small", "Medium", "Large", etc.
#custom_labels = ["Small", "Medium", "Large", "Very Large", "Huge", "Massive"]
#ax.set_xticks([patch.get_x() + patch.get_width() / 2 for patch in bin_edges])
#ax.set_xticklabels(custom_labels, rotation=45, fontsize=12)

plt.title("Distribution of Property Surface", fontsize = 16, fontweight = 'bold')
plt.xlabel('Livable Space', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.ylabel('Count', fontsize = 14, fontweight = 'bold', loc = 'top')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
df_type_room = no_outliers_space.groupby(by = 'Type of Property')[['Number of Rooms']].mean()
plt.figure(figsize = [10, 8])
sns.set_style('whitegrid')
sns.barplot(data = df_type_room, y = 'Type of Property', x='Number of Rooms', orient = 'h')
plt.title("Number of rooms by property type", fontsize = 16, fontweight = 'bold')
plt.xlabel('Average number of rooms', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.ylabel('Property type', fontsize = 14, fontweight = 'bold', loc = 'top')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
no_outliers_space.columns
# Out:
# Index(['Locality', 'Zip Code', 'Province', 'Type of Property',
#        'Subtype of Property', 'Price', 'Number of Rooms', 'Livable Space (m2)',
#        'Fully Equipped Kitchen', 'Furnished', 'Open Fire', 'Terrace',
#        'Terrace Area (m2)', 'Garden', 'Garden Area (m2)', 'Swimming Pool',
#        'Surface of the Land (m2)', 'Number of Facades', 'PEB',
#        'Primary Energy Consumption (kWh/m2)', 'State of the Building',
#        'State of the Building_Numeric', 'PEB_Numeric', 'Province_Numeric',
#        'Type of Property_Numeric', 'Subtype of Property_Grouped',
#        'Subtype of Property_Grouped_Numeric'],
#       dtype='object')

# %%
df_group_room = no_outliers_space.groupby(by = 'Subtype of Property_Grouped')[['Number of Rooms']].mean().sort_values(by = 'Number of Rooms', ascending = True)
plt.figure(figsize = [8, 5])
sns.set_style('whitegrid')
sns.barplot(data = df_group_room, y = 'Subtype of Property_Grouped', x='Number of Rooms')
plt.title("Number of rooms by property group", fontsize = 16, fontweight = 'bold')
plt.xlabel('Average number of rooms', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.ylabel('Property group', fontsize = 14, fontweight = 'bold', loc = 'top')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
df_group_space = no_outliers_space.groupby(by = 'Subtype of Property_Grouped')[['Livable Space (m2)']].mean().sort_values(by = 'Livable Space (m2)', ascending = True)
plt.figure(figsize = [8, 5])
sns.set_style('whitegrid')
sns.barplot(data = df_group_space, y = 'Subtype of Property_Grouped', x='Livable Space (m2)', color = 'darkred')
plt.title("Average living area by property group", fontsize = 16, fontweight = 'bold')
plt.xlabel('Average living area', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.ylabel('Property group', fontsize = 14, fontweight = 'bold', loc = 'top')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
df_province_price = no_outliers_space.groupby(by = 'Province')[['Price']].mean().sort_values(by = 'Price', ascending = False)
plt.figure(figsize = [8, 5])
sns.set_style('whitegrid')
sns.barplot(data = df_province_price, y = 'Province', x='Price', orient = 'h')
plt.title("Average price by Province", fontsize = 16, fontweight = 'bold')
plt.xlabel('Average property price', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.ylabel('Province', fontsize = 14, fontweight = 'bold', loc = 'top')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
df_province_group = no_outliers_space.groupby(by = 'Province')[['Subtype of Property_Grouped']].count().sort_values(by = 'Subtype of Property_Grouped', ascending = False)
plt.figure(figsize = [8, 5])
sns.set_style('whitegrid')
sns.barplot(data = df_province_group, y = 'Province', x='Subtype of Property_Grouped', hue='Subtype of Property_Grouped', orient = 'h')
plt.title("Number property group by Province", fontsize = 16, fontweight = 'bold')
plt.xlabel('Number of property by group', fontsize = 14, fontweight = 'bold', loc = 'right')
plt.ylabel('Province', fontsize = 14, fontweight = 'bold', loc = 'top')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()
